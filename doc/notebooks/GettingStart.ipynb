# %% [markdown]
# # Getting Start

# %% [markdown]
# ## 事前準備

# %% [markdown]
# ### ライブラリのインポート

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### パスの指定

# %%
DATASET_PATH = "../datasets/"
LIB_PATH = "../libs/"

# %% [markdown]
# ### トライアルのデータフレームの取り込み

# %%
df = pd.read_csv(DATASET_PATH + "titanic/train.csv")
df
# Out:
#      Survived  Pclass                                             Name  \
# 0           1       1                    Allen, Miss. Elisabeth Walton
# 1           1       1                   Allison, Master. Hudson Trevor
# 2           0       1                     Allison, Miss. Helen Loraine
# 3           0       1             Allison, Mr. Hudson Joshua Creighton
# 4           0       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..        ...     ...                                              ...
# 886         1       3                              Jermyn, Miss. Annie
# 887         1       3                Johannesen-Bratthammer, Mr. Bernt
# 888         0       3                       Johanson, Mr. Jakob Alfred
# 889         1       3           Johansson Palmquist, Mr. Oskar Leander
# 890         0       3                              Johansson, Mr. Erik
#
#         Sex    Age  SibSp  Parch   Ticket      Fare    Cabin Embarked
# ...

# %% [markdown]
# ## pd_first

# %% [markdown]
# ### pd_firstのインポート

# %%
import sys
sys.path.append(LIB_PATH)

import pd_first

# %% [markdown]
# ### stats

# %%
pd_first.stats(df)
# Out:
#         name    dtype  len  nulls  null percent  nunique  value_counts max  \
# 0   Survived    int64  891      0          0.00        2               497
# 1     Pclass    int64  891      0          0.00        3               323
# 2       Name   object  891      0          0.00      890                 2
# 3        Sex   object  891      0          0.00        2               553
# 4        Age  float64  891     96         10.77       86                37
# 5      SibSp    int64  891      0          0.00        6               587
# 6      Parch    int64  891      0          0.00        7               673
# 7     Ticket   object  891      0          0.00      611                 8
# 8       Fare  float64  891      0          0.00      223                59
# 9      Cabin   object  891    610         68.46      178                 6
# 10  Embarked   object  891      2          0.22        3               628
#
#     value_counts min
# 0                394
# 1                277
# ...

# %% [markdown]
# ### reduce_mem_usage

# %%
df_out = pd_first.reduce_mem_usage(df)
# Out:
# Memory Usage
# Before : 0.3 MB
# After  : 0.27 MB
# 11.18% reduction

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df_out.dtypes
# Out:
# Survived       int8
# Pclass         int8
# Name         object
# Sex          object
# Age         float16
# SibSp          int8
# Parch          int8
# Ticket       object
# Fare        float16
# Cabin        object
# Embarked     object
# dtype: object
